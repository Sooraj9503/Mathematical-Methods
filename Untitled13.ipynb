# %% [markdown]
# <a href="https://colab.research.google.com/github/Sooraj9503/Mathematical-Methods/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x = []
y = []

for i in range(100):
    x.append(i)
    z = 3 - 2 * i * i
    y.append(z)

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = []
y = []

for i in range(50):
  x.append(i)
  #z = (((6 * i)-(12))+3)
  z=6*(i-2)+3
  y.append(z)

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = []
y = []

for i in range(100):
  x.append(i)
  z = ((-(2 * i)-(6)) / (3))
  y.append(z)

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = []
y = []

for i in range(100):
  x.append(i)
  z = (((i / 2) - (1)) * (3))
  y.append(z)

plt.plot(x, y)
plt.show()
