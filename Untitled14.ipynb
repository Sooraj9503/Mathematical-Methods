# %% [markdown]
# <a href="https://colab.research.google.com/github/Sooraj9503/Numerical-Methods/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

M = [[1, 1, 1, 1], [1, 2, 2**2, 2**3], [1, 3, 3**2, 3**3], [1, 3.4, 3.4**2, 3.4**3]]
yv = [1.1, 2.1, 5, 7]
a = np.matmul(np.linalg.inv(M), yv)
x_val = np.arange(0, 4, 0.1)
y_val = []
for x in x_val:
    y_val.append(a[0] + a[1]*x + a[2]*x**2 + a[3]*x**3)
plt.plot(x_val, y_val)
plt.scatter([1, 2, 3, 3.4], [1.1, 2.1, 5, 7], c = 'k')
plt.grid();plt.show()
